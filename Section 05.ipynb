# %% [markdown]
# # Section 5: The inclusion-exclusion principle

# %%
import numpy as np
import matplotlib.pyplot as plt
from venn import *

# %%
V = Venn2()
V.draw_arcs()
V.draw_subset("XdY",labels=True)

# %%
V = Venn3()
V.draw_subset("(XuY)\\Z")
V.draw_arcs(arrows=True)
V.draw_points()
