# %% [markdown]
# # Section 3: Parity

# %%
from basic import *
from domino_board import *

# %%
D6 = domino_board(6)
D6.make_plots()
ax = D6.show_shaded_plot()
for i in range(3):
    for j in range(6):
        D6.add_domino(ax, 2*i, j, 0)

# %%
D5 = domino_board(5)
D5.make_plots()
ax = D5.show_shaded_plot()
for i in range(2):
    for j in range(5):
        D5.add_domino(ax, 2*i, j, 0)
D5.add_domino(ax, 4, 0, 1)
D5.add_domino(ax, 4, 2, 1)
# Out:
# <Axes: >

# %%
D5n = domino_board([(0,0),(4,4)],complement=True)
D5n.make_plots()
ax = D5n.show_shaded_plot()
for x in [[0,1,0],[0,2,1],[0,4,0],[1,0,0],[1,2,1],[2,1,1],[2,3,0],[2,4,0],[3,1,1],[4,0,1],[4,2,1]]:
    D5n.add_domino(ax, *x)
